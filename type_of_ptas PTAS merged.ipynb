# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %%
# Load the dataset
columns = [
    'Family Name',
    'Variation',
    'Algorithm Name',
    'Year',
    'Looked at?',
    'Relevant?',
    'Parallel?',
    'Time Complexity Class',
    'Approximation Factor Class (Mult)',
    'Approximation Factor Class (Add)',
    'Approximation Type (additive/multiplicative)',
    'Parametrized Approximation?',
    'Type of PTAS (if PTAS)',
    'Parametrized Approximation?',
    'Quantum?',
]
approximation_algorithms = pd.read_csv(
    'approximation_algorithms.csv', usecols=columns)

approximation_algorithms

# Clean and prepare the data
approximation_algorithms['Year'] = pd.to_numeric(
    approximation_algorithms['Year'].str.extract(r'(\d{4})')[0], errors='coerce')
approximation_algorithms.dropna(subset=['Year'], inplace=True)
approximation_algorithms['Year'] = approximation_algorithms['Year'].astype(int)

# Filter out irrelevant data
approximation_algorithms = approximation_algorithms[approximation_algorithms['Relevant?'] != 0]
approximation_algorithms = approximation_algorithms[approximation_algorithms['Relevant?'] != '0']

# # Filter out 0.001 looked at
approximation_algorithms = approximation_algorithms[approximation_algorithms['Looked at?'] != '0.001']
approximation_algorithms = approximation_algorithms[approximation_algorithms['Looked at?'] != '0']

# # Filter out Parallel algorithms
approximation_algorithms = approximation_algorithms[approximation_algorithms['Parallel?'] != '1']
approximation_algorithms = approximation_algorithms[approximation_algorithms['Parallel?'] != 1]
approximation_algorithms = approximation_algorithms[approximation_algorithms['Quantum?'] != 1]
approximation_algorithms = approximation_algorithms[approximation_algorithms['Quantum?'] != '1']

# remove '?' from 'Type of PTAS (if PTAS)' column
approximation_algorithms['Type of PTAS (if PTAS)'] = approximation_algorithms['Type of PTAS (if PTAS)'].str.replace('?', '')
# trim leading and trailing whitespaces
approximation_algorithms['Type of PTAS (if PTAS)'] = approximation_algorithms['Type of PTAS (if PTAS)'].str.strip()

# if Type of PTAS (if PTAS) is  NaN and Parametrized Approximation? contains yes or yes?, then it is a "parameterized, non-PTAS" algorithm
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'].isna() & approximation_algorithms['Parametrized Approximation?'].str.contains(
    'yes', case=False, na=False), 'Type of PTAS (if PTAS)'] = 'parameterized, non-PTAS'

# if Type of PTAS (if PTAS) is  NaN and Parametrized Approximation? contains no or no?, then it is a "non-parameterized" algorithm
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'].isna() & approximation_algorithms['Parametrized Approximation?'].str.contains(
    'no', case=False, na=False), 'Type of PTAS (if PTAS)'] = 'non-parameterized'


#  merge all types of PTAS different ['FPTAS', 'FPRAS
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'FPTAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'FPRAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'EPTAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'PTAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'EPRAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'QPTAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'QPRAS', 'Type of PTAS (if PTAS)'] = 'PTAS'
approximation_algorithms.loc[approximation_algorithms['Type of PTAS (if PTAS)'] == 'PRAS', 'Type of PTAS (if PTAS)'] = 'PTAS'





# Sort rows
approximation_algorithms.sort_values(
    by=['Family Name', 'Variation', 'Year'], inplace=True)

approximation_algorithms
# Out:
#                          Family Name Looked at? Relevant?  \
# 152  All-Pairs Shortest Paths (APSP)          1         1
# 153  All-Pairs Shortest Paths (APSP)          1         1
# 154  All-Pairs Shortest Paths (APSP)          1         1
# 155  All-Pairs Shortest Paths (APSP)          1         1
# 156  All-Pairs Shortest Paths (APSP)          1         1
# ..                               ...        ...       ...
# 736         The Vertex Cover Problem          1         1
# 738         The Vertex Cover Problem          1         1
# 884                     Wiener Index          1         1
# 883                     Wiener Index          1         1
# 885                     Wiener Index          1         1
#
#                                              Variation  \
# 152  APSP, unweighted, undirected, no FMM (Approxim...
# 153  APSP, unweighted, undirected, no FMM (Approxim...
# 154  APSP, unweighted, undirected, no FMM (Approxim...
# 155  APSP, unweighted, undirected, no FMM (Approxim...
# 156  APSP, unweighted, undirected, no FMM (Approxim...
# ..                                                 ...
# 736  The Vertex Cover Size Problem, Sparse (Approxi...
# 738  The Vertex Cover Size Problem, Sparse (Approxi...
# 884                   Minimum Wiener Connector problem
# 883                   Minimum Wiener Connector problem
# 885                   Minimum Wiener Connector problem
#
#                                   Algorithm Name  Year Time Complexity Class  \
# 152           Aingworth, Chekuri, Indyk, Motwani  1999                   5.5
# 153               Dor, Halperin, Zwick [APASP_2]  2000                  5.33
# 154               Dor, Halperin, Zwick [APASP_k]  2000                  5.01
# 155           Dor, Halperin, Zwick [APASP_infty]  2000                  5.01
# 156  Deng, Kirkpatrick, Rong, V. Williams, Zhong  2022                  5.29
# ..                                           ...   ...                   ...
# 736                       Biswas, Raman, Saurabh  2020                   NaN
# 738                      Behnezhad [Theorem 1.3]  2021                   NaN
# 884                                          NaN  2008                   5.5
# 883                                    Ruchansky  2015                  5.01
# 885                                          NaN  2023                     7
#
#     Approximation Factor Class (Mult)  Approximation Factor Class (Add)  \
# 152                                 0                              2.00
# 153                                 0                              2.00
# 154                                 0                              3.00
# 155                                 4                              0.00
# 156                                 0                              2.00
# ..                                ...                               ...
# 736                                 3                              0.00
# 738                                 3                              5.99
# 884                                 2                              0.00
# 883                                 4                              0.00
# 885                                 2                              0.00
#
#     Approximation Type (additive/multiplicative) Parametrized Approximation?  \
# 152                                     additive                          no
# 153                                     additive                          no
# 154                                     additive                         yes
# 155                               multiplicative                          no
# 156                                     additive                          no
# ..                                           ...                         ...
# 736                               multiplicative                          no
# 738                      multiplicative-additive                         yes
# 884                               multiplicative                         yes
# 883                               multiplicative                          no
# 885                               multiplicative                         yes
#
#       Type of PTAS (if PTAS) Parallel?  Quantum?
# 152        non-parameterized         0       0.0
# 153        non-parameterized         0       0.0
# 154  parameterized, non-PTAS         0       0.0
# 155        non-parameterized         0       0.0
# 156        non-parameterized         0       0.0
# ..                       ...       ...       ...
# 736        non-parameterized         0       0.0
# 738  parameterized, non-PTAS         0       0.0
# 884                     PTAS         0       0.0
# 883        non-parameterized         0       0.0
# 885                     PTAS         0       0.0
#
# [316 rows x 14 columns]

# %%
# Plot number of approximation algorithms by year
data = approximation_algorithms.copy()


data = data.groupby(['Year']).size()

fig, ax = plt.subplots()
bar_container = ax.bar(data.index, data.values)
# set figure size
fig.set_size_inches(20, 6)
plt.xticks(rotation=60)

plt.margins(x=0.01)



ax.set_xlabel('Year')
ax.set_ylabel('Number of Approximation Algorithms')
ax.set_title('Number of Approximation Algorithms by Year')
plt.show()

# %%
# Plot number of approximation algorithms by decade
data = approximation_algorithms.copy()


data = data.groupby(data['Year'] // 10 * 10).size()

# merge all year <= 1930 into 1930
data[1940] = data.loc[:1940].sum()
data = data.drop(data.loc[:1939].index)


fig, ax = plt.subplots()

bar_container = ax.bar(data.index, data.values, width=5)

# set figure size
fig.set_size_inches(10, 6)

plt.margins(x=0.01)



ax.set_xticks(data.index)
ax.set_xticklabels(['≤1940s'] + [str(year) + 's' for year in data.index[1:]])

ax.set_xlabel('Year')
ax.set_ylabel('Number of Approximation Algorithms')
ax.set_title('Number of Approximation Algorithms by Year')
plt.show()

# %%
# Plot number of approximation algorithms by type of PTAS
data = approximation_algorithms.copy()


# remove '?' from 'Type of PTAS (if PTAS)' column
data['Type of PTAS (if PTAS)'] = data['Type of PTAS (if PTAS)'].str.replace('?', '')

data = data.groupby(['Type of PTAS (if PTAS)']).size()

# sort bars by count
data = data.reindex([ 'PTAS', 'parameterized, non-PTAS', 'non-parameterized'])

# convert values to percentage
percentages = data / data.sum() * 100

colors = [
    '#20a76ecc',
    '#ff8a06cc',
    '#6d29ffcc',
]

fig, ax = plt.subplots()
bar_container = ax.bar(percentages.index, percentages.values, color=colors)
# set figure size
fig.set_size_inches(10, 6)
plt.xticks(rotation=60)

plt.margins(x=0.01)
 
# add labels to bars with percentage and total count
for i, v in enumerate(percentages.values):
    ax.text(i, v + .1, str(round(v, 1)) + '%\n' + ' (' + str(data.values[i]) + ')'
            , ha='center', va='bottom')


ax.set_ymargin(0.1)


ax.set_xlabel('Type of PTAS')

ax.set_ylabel('Number of Approximation Algorithms')

ax.set_title('Number of Approximation Algorithms by Type of PTAS')

plt.show()

# %%
# Plot number of approximation algorithms by type of PTAS by decade
data = approximation_algorithms.copy()

# remove '?' from 'Type of PTAS (if PTAS)' column
data['Type of PTAS (if PTAS)'] = data['Type of PTAS (if PTAS)'].str.replace('?', '')

# merge all year <= 1930 into 1930
data['Year'] = data['Year'] // 10 * 10
data.loc[data['Year'] <= 1940, 'Year'] = 1940


# sort type of PTAS as [ 'PTAS', 'parameterized, non-PTAS', 'non-parameterized']
data['Type of PTAS (if PTAS)'] = pd.Categorical(data['Type of PTAS (if PTAS)'], ['PTAS', 'parameterized, non-PTAS', 'non-parameterized'])


data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()



colors = [
    '#20a76ecc',
    '#ff8a06cc',
    '#6d29ffcc',
]




# plot type of PTAS by year
fig, ax = plt.subplots()

data.unstack().plot(kind='bar', stacked=True, ax=ax, color=colors)



# set figure size
fig.set_size_inches(20, 6)
plt.xticks(rotation=0)

plt.margins(x=0.01)

# first label to ≤1930s
plt.xticks(np.arange(0, len(data.index.levels[0]), 1), ['≤1940s'] + [str(year) + 's' for year in data.index.levels[0][1:]])



ax.set_xlabel('Decade')
ax.set_ylabel('Number of Approximation Algorithms')
ax.set_title('Number of Approximation Algorithms by Decade and Type of PTAS')

ax.legend(title='Type of PTAS')

plt.show()
# Out:
# /var/folders/6k/rf2_mhpd7790drjk7smpzn2r0000gn/T/ipykernel_9827/460640594.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()

# %%
# Plot number of approximation algorithms by type of PTAS by decade
data = approximation_algorithms.copy()

# remove '?' from 'Type of PTAS (if PTAS)' column
data['Type of PTAS (if PTAS)'] = data['Type of PTAS (if PTAS)'].str.replace('?', '')

# merge all year <= 1930 into 1930
data['Year'] = data['Year'] // 10 * 10
data.loc[data['Year'] <= 1940, 'Year'] = 1940


# sort type of PTAS as [ 'PTAS', 'parameterized, non-PTAS', 'non-parameterized']
data['Type of PTAS (if PTAS)'] = pd.Categorical(data['Type of PTAS (if PTAS)'], ['PTAS', 'parameterized, non-PTAS', 'non-parameterized'])


data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()



colors = [
    '#20a76ecc',
    '#ff8a06cc',
    '#6d29ffcc',
]




# plot type of PTAS by year
fig, ax = plt.subplots()

data.unstack().plot(kind='area', stacked=True, ax=ax, color=colors)



# set figure size
fig.set_size_inches(20, 6)
plt.xticks(rotation=0)

plt.margins(x=0.0)

# first label to ≤1930s



ax.set_xlabel('Year')
ax.set_ylabel('Number of Approximation Algorithms')
ax.set_title('Number of Approximation Algorithms by Year and Type of PTAS')
ax.legend(title='Type of PTAS')

plt.show()
# Out:
# /var/folders/6k/rf2_mhpd7790drjk7smpzn2r0000gn/T/ipykernel_9827/1985949437.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()

# %%
# Plot accumulated number of approximation algorithms by year
data = approximation_algorithms.copy()


data['Type of PTAS (if PTAS)'] = pd.Categorical(data['Type of PTAS (if PTAS)'], ['PTAS', 'parameterized, non-PTAS', 'non-parameterized'])


ptas_type_count_per_year = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size().unstack(fill_value=0)

# accumulated number of each type of PTAS per year
ptas_type_count_per_year = ptas_type_count_per_year.cumsum()

colors = [
    '#20a76ecc',
    '#ff8a06cc',
    '#6d29ffcc',
]
fig, ax = plt.subplots()
ptas_type_count_per_year.plot(kind='line', ax=ax , color=colors)
# set figure size
fig.set_size_inches(10, 6)
plt.xticks(rotation=60)
plt.xlim(1940, 2024)

plt.margins(x=0.01)

ax.set_xlabel('Year')
ax.set_ylabel('Number of Approximation Algorithms')
ax.set_title('Accumulated Number of Approximation Algorithms by Year and Type of PTAS')
plt.show()
# Out:
# /var/folders/6k/rf2_mhpd7790drjk7smpzn2r0000gn/T/ipykernel_9827/4073239080.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ptas_type_count_per_year = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size().unstack(fill_value=0)

# %%
data = approximation_algorithms.copy()

types_of_ptas = data['Type of PTAS (if PTAS)'].dropna().unique()


data['Type of PTAS (if PTAS)'] = pd.Categorical(data['Type of PTAS (if PTAS)'], ['PTAS', 'parameterized, non-PTAS', 'non-parameterized'])
colors = [
    '#20a76ecc',
    '#ff8a06cc',
    '#6d29ffcc',
]
# count of each type of PTAS by year
data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()
data = data.unstack(fill_value=0)
fig, ax = plt.subplots(1,1)
fig.set_size_inches(10, 6)
ax.grid(axis='y', alpha=0.4)
ylabels = []
for i, ptas_type in enumerate(types_of_ptas):
    ylabels.append(ptas_type)
print(ylabels)
for i, ptas_type in enumerate(types_of_ptas):
    print(i)
    x = data.index
    y = np.full_like(x, i)
    s = data[ptas_type].values
    ax.scatter(x, y, s=10*s**2, alpha=0.5, label=ptas_type, color=colors[i])


# margin y
ax.set_ylim(-1, len(types_of_ptas))
plt.xlim(1940, 2024)


ax.set_yticks(np.arange(len(types_of_ptas)))
ax.set_yticklabels(ylabels)
ax.set_xlabel('Year')
ax.set_ylabel('Type of PTAS')
ax.set_title('Number of Approximation Algorithms by Type of PTAS and Year')


# plt.legend(title='Type of PTAS')
plt.show()
# Out:
# /var/folders/6k/rf2_mhpd7790drjk7smpzn2r0000gn/T/ipykernel_9827/2762083323.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data = data.groupby(['Year', 'Type of PTAS (if PTAS)']).size()
# ['non-parameterized', 'parameterized, non-PTAS', 'PTAS']
# 0
# 1
# 2
